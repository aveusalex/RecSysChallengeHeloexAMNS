# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Carregando os dados

# %%
# para os users
df_users = pd.read_parquet('../data/DatasetsLimpos/yelp_academic_dataset_user.parquet')

# para os reviews
df_reviews = pd.read_parquet('../data/DatasetsLimpos/yelp_academic_dataset_review.parquet')

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987897 entries, 0 to 1987896
# Data columns (total 19 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   user_id             object
#  1   review_count        float32
#  2   useful              float32
#  3   funny               float32
#  4   cool                float32
#  5   fans                float32
#  6   compliment_hot      float32
#  7   compliment_more     float32
#  8   compliment_profile  float32
#  9   compliment_cute     float32
#  10  compliment_list     float32
#  11  compliment_note     float32
#  12  compliment_plain    float32
#  13  compliment_cool     float32
#  14  compliment_funny    float32
#  15  compliment_writer   float32
#  16  compliment_photos   float32
#  17  account_age         int64
#  18  chato               float32
# dtypes: float32(17), int64(1), object(1)
# memory usage: 159.2+ MB

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6990280 entries, 0 to 6990279
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      object
#  1   business_id  object
#  2   stars        uint8
#  3   useful       int32
#  4   funny        int32
#  5   cool         int32
#  6   text         object
# dtypes: int32(3), object(3), uint8(1)
# memory usage: 246.7+ MB

# %%
df_users.shape, df_reviews.shape
# Out:
# ((1987897, 19), (6990280, 7))

# %%
df_reviews.head()
# Out:
#                   user_id             business_id  stars  useful  funny  cool  \
# 0  mh_-eMZ6K5RLWhZyISBhwA  XQfwVwDr-v0ZS3_CbbE5Xw      3       1      1     1
# 1  OyoGAe7OKpv6SyGZT5g77Q  7ATYjTIgM3jUlt4UM3IypQ      5       1      1     1
# 2  8g_iMtfSiwikVnbP2etR0A  YjUWPpI6HXG530lwP-fb2A      3       1      1     1
# 3  _7bHUi9Uuf5__HHc_Q8guQ  kxX2SOes4o-D3ZQBkiMRfA      5       1      1     1
# 4  bcjbaE6dDog4jkNY91ncLQ  e4Vwtrqf-wpJfwesgvdgxQ      4       1      1     1
#
#                                                 text
# 0  If you decide to eat here, just be aware it is...
# 1  I've taken a lot of spin classes over the year...
# 2  Family diner. Had the buffet. Eclectic assortm...
# 3  Wow!  Yummy, different,  delicious.   Our favo...
# 4  Cute interior and owner (?) gave us tour of up...

# %%
df_users.head()
# Out:
#                   user_id  review_count     useful     funny       cool  \
# 0  qVc8ODYU5SZjKXVBgXdI7w      6.376248   8.884571  7.140230   8.698968
# 1  j14WgRoU_-2ZE1aw1dXrJg      8.374642  10.671132  9.477977  10.214046
# 2  2WnXYQFK0hXEoTxPtV2zvg      6.503866   7.644306  6.920393   6.913457
# 3  SZDeASXq7o05mMNLshsdIA      5.423708   6.243620  5.807296   5.709494
# 4  hA5lMy-EnncsH4JoR-hFGQ      4.403278   3.456893  2.874597   2.274009
#
#        fans  compliment_hot  compliment_more  compliment_profile  \
# 0  5.597378        5.532275         4.215356            4.055574
# 1  8.052207        7.045531         5.586193            5.229601
# 2  4.002198        4.518722         2.754824            2.543041
# 3  3.424858        3.285348         1.904832            1.313262
# 4  1.313262        1.313262         1.313262            1.000000
#
#    compliment_cute  compliment_list  compliment_note  compliment_plain  \
# 0         4.072751         3.031017         5.458386          6.741368
# 1         5.073411         5.536224         7.522789          8.861735
# 2         2.981546         1.743668         4.230015          4.592270
# 3         2.165422         1.551445         2.689090          2.929501
# 4         1.000000         1.000000         1.313262          1.313262
#
#    compliment_cool  compliment_funny  compliment_writer  compliment_photos  \
# 0         6.152133          6.152133           5.487773           5.207945
# 1         8.049975          8.049975           7.328909           7.574927
# 2         4.801709          4.801709           3.630145           3.031017
# 3         3.357534          3.357534           2.543041           2.461150
# 4         1.000000          1.000000           1.000000           1.000000
#
#    account_age     chato
# 0         5864  0.992327
# 1         5133  1.037433
# 2         5317  1.168675
# 3         6286  0.908665
# 4         5884  1.096045

# %% [markdown]
# # Extraindo embeddings dos reviews - text
#
# Para essa task, devemos extrair os embeddinggs de texto dos reviews e estipular uma média para cada usuário.

# %% [markdown]
# OBS: do dataset review, só aproveitamos o texto e o id do usuário.

# %%
# relembrando quantos usuarios tem reviews
df_reviews[df_reviews['text'].notna()].user_id.nunique()
# Out:
# 1987929

# %%
df_users.user_id.nunique()
# Out:
# 1987897

# %%
# agrupando os textos por usuário

# %%
df_reviews_text = df_reviews[['user_id', 'text']].groupby('user_id').agg(lambda x: list(x))

# %%
df_reviews_text.shape
# Out:
# (1987929, 1)

# %% [markdown]
# > O dataframe contém, por usuário, uma lista de reviews (textos).

# %% [markdown]
# ## Extraindo os embeddings

# %%
import torch
from transformers import BertTokenizer, BertModel
import time
from multiprocessing import  Pool


# Load pretrained model/tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased', output_hidden_states=True).to('cuda')
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def get_bert_embedding(text_list):
    # if text_list is over than 15 items, split it in groups of 15
    # print(len(text_list))
    if len(text_list) > 15:
        # print("Text list is over than 15 items, split it in groups of 15")
        text_list = [text_list[i:i + 15] for i in range(0, len(text_list), 15)]
    else:
        text_list = [text_list]
    embs = []
    for text in text_list:
        start = time.time()
        tokens = []
        # clip text if it is too long (more than 512 tokens)
        for idx in range(len(text)):
            if len(text[idx]) > 512:
                text[idx] = text[idx][:510]
            # Add the special tokens.
            marked_text = "[CLS] " + text[idx] + " [SEP]"
            # Split the sentence into tokens.
            tokenized_text = tokenizer.tokenize(marked_text)
            # padding if text is less than 512 tokens
            if len(tokenized_text) < 512:
                tokenized_text = tokenized_text + ["[PAD]"] * (512 - len(tokenized_text))
            # Map the token strings to their vocabulary indexes.
            indexed_tokens = tokenizer.convert_tokens_to_ids(tokenized_text)
            tokens.append(indexed_tokens)
        # Convert inputs to PyTorch tensors and put them on GPU
        tokens_tensor = torch.tensor(tokens).to('cuda')

        # Put the model in "evaluation" mode,meaning feed-forward operation.
        model.eval()
        # Run the text through BERT, and collect all the hidden states produced from all 12 layers.
        with torch.no_grad():
            outputs = model(tokens_tensor)[2][-4:]

        # sum of last four layer
        outputs = torch.stack(outputs, dim=1)
        outputs = outputs.sum(1)
        # mean of the tokens, results in one vector of 768 dimensions per text
        outputs = torch.mean(outputs, 1).squeeze(0).cpu().numpy()
        print("Time to get embedding: ", time.time() - start)
        embs.append(outputs)
    return embs

# %%
# extraindo os embeddings
df_reviews_text['embeddings'] = df_reviews_text['text'].apply(get_bert_embedding)
# Out:
# Time to get embedding:  0.09251761436462402
# Time to get embedding:  0.049523353576660156
# Time to get embedding:  0.047005414962768555
# Time to get embedding:  0.07351374626159668
# Time to get embedding:  0.05051612854003906
# Time to get embedding:  0.11351823806762695
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.09451460838317871
# Time to get embedding:  0.027004003524780273
# Time to get embedding:  0.07251334190368652
# Time to get embedding:  0.22604703903198242
# Time to get embedding:  0.1390388011932373
# Time to get embedding:  0.02699565887451172
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.02400517463684082
# Time to get embedding:  0.07251214981079102
# Time to get embedding:  0.07210922241210938
# Time to get embedding:  0.028000354766845703
# Time to get embedding:  0.09351706504821777
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.026514768600463867
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.07052063941955566
# Time to get embedding:  0.04900026321411133
# Time to get embedding:  0.027001142501831055
# Time to get embedding:  0.07051515579223633
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.026517868041992188
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.02500128746032715
# Time to get embedding:  0.025998592376708984
# Time to get embedding:  0.11552023887634277
# Time to get embedding:  0.026513099670410156
# Time to get embedding:  0.3405575752258301
# Time to get embedding:  0.04951667785644531
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.024005651473999023
# Time to get embedding:  0.025511980056762695
# Time to get embedding:  0.024988651275634766
# Time to get embedding:  0.023999929428100586
# Time to get embedding:  0.027010679244995117
# Time to get embedding:  0.026535749435424805
# Time to get embedding:  0.11151838302612305
# Time to get embedding:  0.0945124626159668
# Time to get embedding:  0.07100534439086914
# Time to get embedding:  0.026515722274780273
# Time to get embedding:  0.02400064468383789
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.02400493621826172
# Time to get embedding:  0.07151412963867188
# Time to get embedding:  0.05053877830505371
# Time to get embedding:  0.024979591369628906
# Time to get embedding:  0.026001691818237305
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.04851412773132324
# Time to get embedding:  0.2270336151123047
# Time to get embedding:  0.02700519561767578
# Time to get embedding:  0.025511980056762695
# Time to get embedding:  0.0469975471496582
# Time to get embedding:  0.04851889610290527
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.3395555019378662
# Time to get embedding:  0.051516056060791016
# Time to get embedding:  0.05100727081298828
# Time to get embedding:  0.1616837978363037
# Time to get embedding:  0.028000593185424805
# Time to get embedding:  0.02451157569885254
# Time to get embedding:  0.11152338981628418
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.027001142501831055
# Time to get embedding:  0.050339698791503906
# Time to get embedding:  0.34154748916625977
# Time to get embedding:  0.07051777839660645
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.04652118682861328
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.08951854705810547
# Time to get embedding:  0.18103504180908203
# Time to get embedding:  0.0735175609588623
# Time to get embedding:  0.025998353958129883
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.02400493621826172
# Time to get embedding:  0.1570274829864502
# Time to get embedding:  0.34156274795532227
# Time to get embedding:  0.2485485076904297
# Time to get embedding:  0.02900075912475586
# Time to get embedding:  0.0941934585571289
# Time to get embedding:  0.027005672454833984
# Time to get embedding:  0.025209665298461914
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.025000572204589844
# Time to get embedding:  0.33907437324523926
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.026007890701293945
# Time to get embedding:  0.07023239135742188
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.15803074836730957
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.3380699157714844
# Time to get embedding:  0.3375556468963623
# Time to get embedding:  0.13751769065856934
# Time to get embedding:  0.025519132614135742
# Time to get embedding:  0.13651514053344727
# Time to get embedding:  0.09051918983459473
# Time to get embedding:  0.023999691009521484
# Time to get embedding:  0.048506736755371094
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.3585638999938965
# Time to get embedding:  0.3520824909210205
# Time to get embedding:  0.3515608310699463
# Time to get embedding:  0.3500638008117676
# Time to get embedding:  0.14052271842956543
# Time to get embedding:  0.02551126480102539
# Time to get embedding:  0.04999971389770508
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.15864157676696777
# Time to get embedding:  0.026999711990356445
# Time to get embedding:  0.2965567111968994
# Time to get embedding:  0.09452557563781738
# Time to get embedding:  0.02600383758544922
# Time to get embedding:  0.051529645919799805
# Time to get embedding:  0.026999473571777344
# Time to get embedding:  0.025005102157592773
# Time to get embedding:  0.024514198303222656
# Time to get embedding:  0.027005672454833984
# Time to get embedding:  0.13951706886291504
# Time to get embedding:  0.05051374435424805
# Time to get embedding:  0.3385648727416992
# Time to get embedding:  0.04952120780944824
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.027001619338989258
# Time to get embedding:  0.025513887405395508
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.025000572204589844
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.02652120590209961
# Time to get embedding:  0.025998353958129883
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.09152674674987793
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.025096654891967773
# Time to get embedding:  0.026001453399658203
# Time to get embedding:  0.048999786376953125
# Time to get embedding:  0.02752399444580078
# Time to get embedding:  0.11051082611083984
# Time to get embedding:  0.024998188018798828
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.04851984977722168
# Time to get embedding:  0.344407320022583
# Time to get embedding:  0.05052900314331055
# Time to get embedding:  0.08851790428161621
# Time to get embedding:  0.09000444412231445
# Time to get embedding:  0.3370676040649414
# Time to get embedding:  0.3335535526275635
# Time to get embedding:  0.3295626640319824
# Time to get embedding:  0.34006524085998535
# Time to get embedding:  0.3355579376220703
# Time to get embedding:  0.34407544136047363
# Time to get embedding:  0.3415491580963135
# Time to get embedding:  0.34213685989379883
# Time to get embedding:  0.34406208992004395
# Time to get embedding:  0.3465564250946045
# Time to get embedding:  0.343066930770874
# Time to get embedding:  0.34654903411865234
# Time to get embedding:  0.3450660705566406
# Time to get embedding:  0.3415498733520508
# Time to get embedding:  0.13902688026428223
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.11651611328125
# Time to get embedding:  0.02700495719909668
# Time to get embedding:  0.025003433227539062
# Time to get embedding:  0.02651500701904297
# Time to get embedding:  0.025000572204589844
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.024007320404052734
# Time to get embedding:  0.024507761001586914
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.09251832962036133
# Time to get embedding:  0.09351682662963867
# Time to get embedding:  0.07352089881896973
# Time to get embedding:  0.09151387214660645
# Time to get embedding:  0.13651680946350098
# Time to get embedding:  0.14052438735961914
# Time to get embedding:  0.06929492950439453
# Time to get embedding:  0.05242180824279785
# Time to get embedding:  0.33944129943847656
# Time to get embedding:  0.3480713367462158
# Time to get embedding:  0.0279996395111084
# Time to get embedding:  0.07451820373535156
# Time to get embedding:  0.05299973487854004
# Time to get embedding:  0.2575540542602539
# Time to get embedding:  0.29755139350891113
# Time to get embedding:  0.028000354766845703
# Time to get embedding:  0.34355759620666504
# Time to get embedding:  0.0925140380859375
# Time to get embedding:  0.04951977729797363
# Time to get embedding:  0.025995731353759766
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.05051279067993164
# Time to get embedding:  0.029000043869018555
# Time to get embedding:  0.025011539459228516
# Time to get embedding:  0.07050657272338867
# Time to get embedding:  0.02700638771057129
# Time to get embedding:  0.02451300621032715
# Time to get embedding:  0.11651897430419922
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.024998903274536133
# Time to get embedding:  0.02551889419555664
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.09351515769958496
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.028522253036499023
# Time to get embedding:  0.16251444816589355
# Time to get embedding:  0.02700495719909668
# Time to get embedding:  0.028514862060546875
# Time to get embedding:  0.048999786376953125
# Time to get embedding:  0.026515960693359375
# Time to get embedding:  0.09400391578674316
# Time to get embedding:  0.05308032035827637
# Time to get embedding:  0.20703458786010742
# Time to get embedding:  0.05151796340942383
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.026999711990356445
# Time to get embedding:  0.20405340194702148
# Time to get embedding:  0.026004791259765625
# Time to get embedding:  0.02551126480102539
# Time to get embedding:  0.09051918983459473
# Time to get embedding:  0.025998592376708984
# Time to get embedding:  0.0290067195892334
# Time to get embedding:  0.025998353958129883
# Time to get embedding:  0.025513887405395508
# Time to get embedding:  0.22603774070739746
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.02451324462890625
# Time to get embedding:  0.02500152587890625
# Time to get embedding:  0.025998830795288086
# Time to get embedding:  0.0475156307220459
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.02500629425048828
# Time to get embedding:  0.09252285957336426
# Time to get embedding:  0.04951024055480957
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.06851840019226074
# Time to get embedding:  0.027001380920410156
# Time to get embedding:  0.13351964950561523
# Time to get embedding:  0.06951332092285156
# Time to get embedding:  0.029012203216552734
# Time to get embedding:  0.024530410766601562
# Time to get embedding:  0.047998905181884766
# Time to get embedding:  0.09051656723022461
# Time to get embedding:  0.07051563262939453
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.06952571868896484
# Time to get embedding:  0.2695503234863281
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.06751823425292969
# Time to get embedding:  0.06951737403869629
# Time to get embedding:  0.33655691146850586
# Time to get embedding:  0.11351561546325684
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.025156259536743164
# Time to get embedding:  0.024995803833007812
# Time to get embedding:  0.0705251693725586
# Time to get embedding:  0.09400653839111328
# Time to get embedding:  0.025510787963867188
# Time to get embedding:  0.13551688194274902
# Time to get embedding:  0.02801203727722168
# Time to get embedding:  0.025511503219604492
# Time to get embedding:  0.023999691009521484
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.0711970329284668
# Time to get embedding:  0.07252740859985352
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.18103384971618652
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.02700495719909668
# Time to get embedding:  0.027515172958374023
# Time to get embedding:  0.051999807357788086
# Time to get embedding:  0.02800726890563965
# Time to get embedding:  0.026244640350341797
# Time to get embedding:  0.027007579803466797
# Time to get embedding:  0.025992393493652344
# Time to get embedding:  0.028203964233398438
# Time to get embedding:  0.11952853202819824
# Time to get embedding:  0.02699899673461914
# Time to get embedding:  0.02799701690673828
# Time to get embedding:  0.030531883239746094
# Time to get embedding:  0.02999711036682129
# Time to get embedding:  0.2500419616699219
# Time to get embedding:  0.07151246070861816
# Time to get embedding:  0.025005102157592773
# Time to get embedding:  0.09251236915588379
# Time to get embedding:  0.050538063049316406
# Time to get embedding:  0.11451220512390137
# Time to get embedding:  0.09424591064453125
# Time to get embedding:  0.051007986068725586
# Time to get embedding:  0.02651381492614746
# Time to get embedding:  0.07000517845153809
# Time to get embedding:  0.02651047706604004
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.0460052490234375
# Time to get embedding:  0.11358857154846191
# Time to get embedding:  0.04999995231628418
# Time to get embedding:  0.025002717971801758
# Time to get embedding:  0.02551746368408203
# Time to get embedding:  0.04900002479553223
# Time to get embedding:  0.025998830795288086
# Time to get embedding:  0.09447550773620605
# Time to get embedding:  0.02650928497314453
# Time to get embedding:  0.06900548934936523
# Time to get embedding:  0.025007247924804688
# Time to get embedding:  0.025517940521240234
# Time to get embedding:  0.023999929428100586
# Time to get embedding:  0.28548240661621094
# Time to get embedding:  0.028006792068481445
# Time to get embedding:  0.05053067207336426
# Time to get embedding:  0.053003549575805664
# Time to get embedding:  0.10254883766174316
# Time to get embedding:  0.03000187873840332
# Time to get embedding:  0.026381254196166992
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.026003599166870117
# Time to get embedding:  0.047522544860839844
# Time to get embedding:  0.026993989944458008
# Time to get embedding:  0.0915224552154541
# Time to get embedding:  0.03000020980834961
# Time to get embedding:  0.22860336303710938
# Time to get embedding:  0.0270078182220459
# Time to get embedding:  0.02599191665649414
# Time to get embedding:  0.027004480361938477
# Time to get embedding:  0.02533864974975586
# Time to get embedding:  0.025007247924804688
# Time to get embedding:  0.025992393493652344
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.02552032470703125
# Time to get embedding:  0.07299923896789551
# Time to get embedding:  0.06852579116821289
# Time to get embedding:  0.2500638961791992
# Time to get embedding:  0.02851390838623047
# Time to get embedding:  0.02599644660949707
# Time to get embedding:  0.08936119079589844
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.02652764320373535
# Time to get embedding:  0.02899956703186035
# Time to get embedding:  0.04900479316711426
# Time to get embedding:  0.09046578407287598
# Time to get embedding:  0.02652263641357422
# Time to get embedding:  0.2030322551727295
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.049002885818481445
# Time to get embedding:  0.0265195369720459
# Time to get embedding:  0.02500176429748535
# Time to get embedding:  0.03700447082519531
# Time to get embedding:  0.03554344177246094
# Time to get embedding:  0.05000138282775879
# Time to get embedding:  0.02600836753845215
# Time to get embedding:  0.2923891544342041
# Time to get embedding:  0.026512622833251953
# Time to get embedding:  0.05000042915344238
# Time to get embedding:  0.049466848373413086
# Time to get embedding:  0.026001930236816406
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.07051205635070801
# Time to get embedding:  0.049338579177856445
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.025999069213867188
# Time to get embedding:  0.1800394058227539
# Time to get embedding:  0.026996850967407227
# Time to get embedding:  0.025008440017700195
# Time to get embedding:  0.02530956268310547
# Time to get embedding:  0.025996923446655273
# Time to get embedding:  0.0915215015411377
# Time to get embedding:  0.0735177993774414
# Time to get embedding:  0.07200098037719727
# Time to get embedding:  0.02651810646057129
# Time to get embedding:  0.02600264549255371
# Time to get embedding:  0.07551264762878418
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.05200529098510742
# Time to get embedding:  0.02651524543762207
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.1125180721282959
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.028537273406982422
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.026018857955932617
# Time to get embedding:  0.14004039764404297
# Time to get embedding:  0.05099844932556152
# Time to get embedding:  0.025522708892822266
# Time to get embedding:  0.024999380111694336
# Time to get embedding:  0.07000565528869629
# Time to get embedding:  0.02651357650756836
# Time to get embedding:  0.02600693702697754
# Time to get embedding:  0.025992631912231445
# Time to get embedding:  0.026521921157836914
# Time to get embedding:  0.04799938201904297
# Time to get embedding:  0.02700066566467285
# Time to get embedding:  0.02452254295349121
# Time to get embedding:  0.02500605583190918
# Time to get embedding:  0.05100440979003906
# Time to get embedding:  0.2030320167541504
# Time to get embedding:  0.02752971649169922
# Time to get embedding:  0.05100083351135254
# Time to get embedding:  0.16003775596618652
# Time to get embedding:  0.026004791259765625
# Time to get embedding:  0.34656286239624023
# Time to get embedding:  0.3357069492340088
# Time to get embedding:  0.33955883979797363
# Time to get embedding:  0.18303656578063965
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.026515960693359375
# Time to get embedding:  0.11151885986328125
# Time to get embedding:  0.04799985885620117
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.024518728256225586
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.028000354766845703
# Time to get embedding:  0.026006698608398438
# Time to get embedding:  0.2615547180175781
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.05151939392089844
# Time to get embedding:  0.11852645874023438
# Time to get embedding:  0.028000354766845703
# Time to get embedding:  0.027515888214111328
# Time to get embedding:  0.08000445365905762
# Time to get embedding:  0.02951335906982422
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.05100679397583008
# Time to get embedding:  0.05451345443725586
# Time to get embedding:  0.052518606185913086
# Time to get embedding:  0.0260007381439209
# Time to get embedding:  0.2670423984527588
# Time to get embedding:  0.028509855270385742
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.07251930236816406
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.027517080307006836
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.02900218963623047
# Time to get embedding:  0.15903425216674805
# Time to get embedding:  0.026998043060302734
# Time to get embedding:  0.025000810623168945
# Time to get embedding:  0.026004791259765625
# Time to get embedding:  0.025513887405395508
# Time to get embedding:  0.04699873924255371
# Time to get embedding:  0.026012420654296875
# Time to get embedding:  0.025511980056762695
# Time to get embedding:  0.026001930236816406
# Time to get embedding:  0.023998022079467773
# Time to get embedding:  0.18606066703796387
# Time to get embedding:  0.05151844024658203
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.09451651573181152
# Time to get embedding:  0.025996685028076172
# Time to get embedding:  0.025000572204589844
# Time to get embedding:  0.04852604866027832
# Time to get embedding:  0.026995182037353516
# Time to get embedding:  0.06933164596557617
# Time to get embedding:  0.24803566932678223
# Time to get embedding:  0.13904237747192383
# Time to get embedding:  0.0709991455078125
# Time to get embedding:  0.02752208709716797
# Time to get embedding:  0.04900026321411133
# Time to get embedding:  0.10951900482177734
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.026508808135986328
# Time to get embedding:  0.1790330410003662
# Time to get embedding:  0.05099964141845703
# Time to get embedding:  0.07251882553100586
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.11551833152770996
# Time to get embedding:  0.027006149291992188
# Time to get embedding:  0.02751326560974121
# Time to get embedding:  0.11251020431518555
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.02600574493408203
# Time to get embedding:  0.18102645874023438
# Time to get embedding:  0.02601003646850586
# Time to get embedding:  0.09409713745117188
# Time to get embedding:  0.02651214599609375
# Time to get embedding:  0.27161145210266113
# Time to get embedding:  0.02850937843322754
# Time to get embedding:  0.049001455307006836
# Time to get embedding:  0.027004241943359375
# Time to get embedding:  0.09151077270507812
# Time to get embedding:  0.025069475173950195
# Time to get embedding:  0.3385498523712158
# Time to get embedding:  0.3205585479736328
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.025510787963867188
# Time to get embedding:  0.04899907112121582
# Time to get embedding:  0.02800583839416504
# Time to get embedding:  0.026510000228881836
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.070526123046875
# Time to get embedding:  0.05399966239929199
# Time to get embedding:  0.026511430740356445
# Time to get embedding:  0.026009321212768555
# Time to get embedding:  0.07200217247009277
# Time to get embedding:  0.025514602661132812
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.16203975677490234
# Time to get embedding:  0.12151694297790527
# Time to get embedding:  0.07452964782714844
# Time to get embedding:  0.07199382781982422
# Time to get embedding:  0.34588122367858887
# Time to get embedding:  0.028003215789794922
# Time to get embedding:  0.02799677848815918
# Time to get embedding:  0.025519371032714844
# Time to get embedding:  0.027001380920410156
# Time to get embedding:  0.07051682472229004
# Time to get embedding:  0.028000593185424805
# Time to get embedding:  0.07353091239929199
# Time to get embedding:  0.025995731353759766
# Time to get embedding:  0.34136223793029785
# Time to get embedding:  0.11552786827087402
# Time to get embedding:  0.026485681533813477
# Time to get embedding:  0.0260007381439209
# Time to get embedding:  0.14152812957763672
# Time to get embedding:  0.027518272399902344
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.0240023136138916
# Time to get embedding:  0.025002479553222656
# Time to get embedding:  0.047513723373413086
# Time to get embedding:  0.025996685028076172
# Time to get embedding:  0.04853081703186035
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.047514915466308594
# Time to get embedding:  0.34856557846069336
# Time to get embedding:  0.3428530693054199
# Time to get embedding:  0.07400321960449219
# Time to get embedding:  0.09152626991271973
# Time to get embedding:  0.09451961517333984
# Time to get embedding:  0.02700638771057129
# Time to get embedding:  0.2725553512573242
# Time to get embedding:  0.02800464630126953
# Time to get embedding:  0.02451038360595703
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.025006532669067383
# Time to get embedding:  0.22754812240600586
# Time to get embedding:  0.02700066566467285
# Time to get embedding:  0.025999069213867188
# Time to get embedding:  0.025005340576171875
# Time to get embedding:  0.04851031303405762
# Time to get embedding:  0.04800605773925781
# Time to get embedding:  0.026514291763305664
# Time to get embedding:  0.13851499557495117
# Time to get embedding:  0.20003533363342285
# Time to get embedding:  0.04751873016357422
# Time to get embedding:  0.027002334594726562
# Time to get embedding:  0.02699756622314453
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.13302874565124512
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.02500462532043457
# Time to get embedding:  0.02351093292236328
# Time to get embedding:  0.023999929428100586
# Time to get embedding:  0.09251904487609863
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.3400750160217285
# Time to get embedding:  0.33657288551330566
# Time to get embedding:  0.33655285835266113
# Time to get embedding:  0.33867502212524414
# Time to get embedding:  0.3395540714263916
# Time to get embedding:  0.3375585079193115
# Time to get embedding:  0.07309532165527344
# Time to get embedding:  0.027008533477783203
# Time to get embedding:  0.11103630065917969
# Time to get embedding:  0.0280001163482666
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.13503003120422363
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.11451840400695801
# Time to get embedding:  0.16003751754760742
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.026516437530517578
# Time to get embedding:  0.026001691818237305
# Time to get embedding:  0.34655046463012695
# Time to get embedding:  0.324570894241333
# Time to get embedding:  0.25954675674438477
# Time to get embedding:  0.02700495719909668
# Time to get embedding:  0.09351158142089844
# Time to get embedding:  0.027088403701782227
# Time to get embedding:  0.026004314422607422
# Time to get embedding:  0.024996519088745117
# Time to get embedding:  0.0279996395111084
# Time to get embedding:  0.1135246753692627
# Time to get embedding:  0.02750992774963379
# Time to get embedding:  0.09116983413696289
# Time to get embedding:  0.05099940299987793
# Time to get embedding:  0.049518585205078125
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.02699875831604004
# Time to get embedding:  0.025004148483276367
# Time to get embedding:  0.04752087593078613
# Time to get embedding:  0.05000734329223633
# Time to get embedding:  0.04851198196411133
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.026006698608398438
# Time to get embedding:  0.02551412582397461
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.07351851463317871
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.0955348014831543
# Time to get embedding:  0.025995969772338867
# Time to get embedding:  0.025003910064697266
# Time to get embedding:  0.02451634407043457
# Time to get embedding:  0.04999852180480957
# Time to get embedding:  0.028005361557006836
# Time to get embedding:  0.0255124568939209
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.02551579475402832
# Time to get embedding:  0.0260012149810791
# Time to get embedding:  0.09451627731323242
# Time to get embedding:  0.0715188980102539
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.1620466709136963
# Time to get embedding:  0.027001619338989258
# Time to get embedding:  0.04851579666137695
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.04851889610290527
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.07251358032226562
# Time to get embedding:  0.050000905990600586
# Time to get embedding:  0.026999235153198242
# Time to get embedding:  0.3005523681640625
# Time to get embedding:  0.027515888214111328
# Time to get embedding:  0.04999995231628418
# Time to get embedding:  0.07052493095397949
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.04952692985534668
# Time to get embedding:  0.07251906394958496
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.027994632720947266
# Time to get embedding:  0.11551713943481445
# Time to get embedding:  0.029093027114868164
# Time to get embedding:  0.3435530662536621
# Time to get embedding:  0.050005197525024414
# Time to get embedding:  0.3380703926086426
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.026013851165771484
# Time to get embedding:  0.02651047706604004
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.06951904296875
# Time to get embedding:  0.026999711990356445
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.027511119842529297
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.024998903274536133
# Time to get embedding:  0.04651951789855957
# Time to get embedding:  0.04799938201904297
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.04951119422912598
# Time to get embedding:  0.02499866485595703
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.02451491355895996
# Time to get embedding:  0.02599811553955078
# Time to get embedding:  0.023999691009521484
# Time to get embedding:  0.02500605583190918
# Time to get embedding:  0.026511430740356445
# Time to get embedding:  0.051000118255615234
# Time to get embedding:  0.04752016067504883
# Time to get embedding:  0.048999786376953125
# Time to get embedding:  0.04851412773132324
# Time to get embedding:  0.027000904083251953
# Time to get embedding:  0.025999069213867188
# Time to get embedding:  0.026007413864135742
# Time to get embedding:  0.0255124568939209
# Time to get embedding:  0.0905141830444336
# Time to get embedding:  0.026002883911132812
# Time to get embedding:  0.027999162673950195
# Time to get embedding:  0.08951663970947266
# Time to get embedding:  0.04900693893432617
# Time to get embedding:  0.027511119842529297
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.06952714920043945
# Time to get embedding:  0.049002647399902344
# Time to get embedding:  0.04951000213623047
# Time to get embedding:  0.02400040626525879
# Time to get embedding:  0.02700495719909668
# Time to get embedding:  0.02651810646057129
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.13652443885803223
# Time to get embedding:  0.026511430740356445
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.09051752090454102
# Time to get embedding:  0.33455324172973633
# Time to get embedding:  0.09551572799682617
# Time to get embedding:  0.05151963233947754
# Time to get embedding:  0.05099892616271973
# Time to get embedding:  0.027005672454833984
# Time to get embedding:  0.16203713417053223
# Time to get embedding:  0.05051612854003906
# Time to get embedding:  0.05099844932556152
# Time to get embedding:  0.05018734931945801
# Time to get embedding:  0.051998138427734375
# Time to get embedding:  0.1140444278717041
# Time to get embedding:  0.07151436805725098
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.026005983352661133
# Time to get embedding:  0.025510072708129883
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.16004610061645508
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.049521684646606445
# Time to get embedding:  0.11751723289489746
# Time to get embedding:  0.05200052261352539
# Time to get embedding:  0.3327624797821045
# Time to get embedding:  0.3405458927154541
# Time to get embedding:  0.09651780128479004
# Time to get embedding:  0.09851694107055664
# Time to get embedding:  0.09551739692687988
# Time to get embedding:  0.0735161304473877
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.2030341625213623
# Time to get embedding:  0.026006460189819336
# Time to get embedding:  0.025997400283813477
# Time to get embedding:  0.04751443862915039
# Time to get embedding:  0.20603418350219727
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.02551102638244629
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.0255129337310791
# Time to get embedding:  0.07001686096191406
# Time to get embedding:  0.028519392013549805
# Time to get embedding:  0.02599620819091797
# Time to get embedding:  0.3305480480194092
# Time to get embedding:  0.32907938957214355
# Time to get embedding:  0.33155345916748047
# Time to get embedding:  0.13451552391052246
# Time to get embedding:  0.025515317916870117
# Time to get embedding:  0.04899954795837402
# Time to get embedding:  0.0515284538269043
# Time to get embedding:  0.02800297737121582
# Time to get embedding:  0.02599644660949707
# Time to get embedding:  0.34807682037353516
# Time to get embedding:  0.3495492935180664
# Time to get embedding:  0.3460817337036133
# Time to get embedding:  0.2720320224761963
# Time to get embedding:  0.11452484130859375
# Time to get embedding:  0.025511741638183594
# Time to get embedding:  0.02500128746032715
# Time to get embedding:  0.024998188018798828
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.07151508331298828
# Time to get embedding:  0.13552117347717285
# Time to get embedding:  0.27054548263549805
# Time to get embedding:  0.028005123138427734
# Time to get embedding:  0.02551102638244629
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.025512218475341797
# Time to get embedding:  0.08951616287231445
# Time to get embedding:  0.0279996395111084
# Time to get embedding:  0.04900479316711426
# Time to get embedding:  0.07351398468017578
# Time to get embedding:  0.026007413864135742
# Time to get embedding:  0.2555422782897949
# Time to get embedding:  0.02700185775756836
# Time to get embedding:  0.2705519199371338
# Time to get embedding:  0.026998519897460938
# Time to get embedding:  0.026004314422607422
# Time to get embedding:  0.02451491355895996
# Time to get embedding:  0.02600240707397461
# Time to get embedding:  0.24304437637329102
# Time to get embedding:  0.15602898597717285
# Time to get embedding:  0.06908917427062988
# Time to get embedding:  0.027001142501831055
# Time to get embedding:  0.026999235153198242
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.04651379585266113
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.027013063430786133
# Time to get embedding:  0.15902137756347656
# Time to get embedding:  0.027999401092529297
# Time to get embedding:  0.14003849029541016
# Time to get embedding:  0.13952136039733887
# Time to get embedding:  0.027002334594726562
# Time to get embedding:  0.026514053344726562
# Time to get embedding:  0.04799962043762207
# Time to get embedding:  0.026005029678344727
# Time to get embedding:  0.024510860443115234
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.02499842643737793
# Time to get embedding:  0.02500748634338379
# Time to get embedding:  0.04851412773132324
# Time to get embedding:  0.07051467895507812
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.06951785087585449
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.05099987983703613
# Time to get embedding:  0.04852795600891113
# Time to get embedding:  0.024990081787109375
# Time to get embedding:  0.1470339298248291
# Time to get embedding:  0.0280001163482666
# Time to get embedding:  0.34255027770996094
# Time to get embedding:  0.27555322647094727
# Time to get embedding:  0.026999711990356445
# Time to get embedding:  0.0265195369720459
# Time to get embedding:  0.04800081253051758
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.049527883529663086
# Time to get embedding:  0.09251642227172852
# Time to get embedding:  0.17852163314819336
# Time to get embedding:  0.026512861251831055
# Time to get embedding:  0.04799985885620117
# Time to get embedding:  0.050514936447143555
# Time to get embedding:  0.025002479553222656
# Time to get embedding:  0.024997949600219727
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.024515628814697266
# Time to get embedding:  0.3345508575439453
# Time to get embedding:  0.33055615425109863
# Time to get embedding:  0.0725104808807373
# Time to get embedding:  0.02600574493408203
# Time to get embedding:  0.0255126953125
# Time to get embedding:  0.04799985885620117
# Time to get embedding:  0.027007102966308594
# Time to get embedding:  0.048513174057006836
# Time to get embedding:  0.029008150100708008
# Time to get embedding:  0.11451077461242676
# Time to get embedding:  0.04851508140563965
# Time to get embedding:  0.2440347671508789
# Time to get embedding:  0.26569676399230957
# Time to get embedding:  0.028000354766845703
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.025510787963867188
# Time to get embedding:  0.024999380111694336
# Time to get embedding:  0.04800534248352051
# Time to get embedding:  0.06851363182067871
# Time to get embedding:  0.027001142501831055
# Time to get embedding:  0.1105194091796875
# Time to get embedding:  0.07045578956604004
# Time to get embedding:  0.0735166072845459
# Time to get embedding:  0.06851768493652344
# Time to get embedding:  0.04800105094909668
# Time to get embedding:  0.04752683639526367
# Time to get embedding:  0.025002717971801758
# Time to get embedding:  0.06900310516357422
# Time to get embedding:  0.025512218475341797
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.024001121520996094
# Time to get embedding:  0.026006698608398438
# Time to get embedding:  0.22154021263122559
# Time to get embedding:  0.09045624732971191
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.2069082260131836
# Time to get embedding:  0.026999473571777344
# Time to get embedding:  0.1410362720489502
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.026009798049926758
# Time to get embedding:  0.026506662368774414
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.02500438690185547
# Time to get embedding:  0.11407256126403809
# Time to get embedding:  0.02751946449279785
# Time to get embedding:  0.07200002670288086
# Time to get embedding:  0.34094715118408203
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.025999069213867188
# Time to get embedding:  0.048519134521484375
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.049005746841430664
# Time to get embedding:  0.026513338088989258
# Time to get embedding:  0.0280001163482666
# Time to get embedding:  0.18703413009643555
# Time to get embedding:  0.05100727081298828
# Time to get embedding:  0.05050921440124512
# Time to get embedding:  0.026000499725341797
# Time to get embedding:  0.1325225830078125
# Time to get embedding:  0.11804962158203125
# Time to get embedding:  0.04999947547912598
# Time to get embedding:  0.3450779914855957
# Time to get embedding:  0.11751413345336914
# Time to get embedding:  0.09451746940612793
# Time to get embedding:  0.05000042915344238
# Time to get embedding:  0.02851724624633789
# Time to get embedding:  0.048999786376953125
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.13703513145446777
# Time to get embedding:  0.05099987983703613
# Time to get embedding:  0.02500605583190918
# Time to get embedding:  0.049513816833496094
# Time to get embedding:  0.07251405715942383
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.0715179443359375
# Time to get embedding:  0.20603513717651367
# Time to get embedding:  0.02699899673461914
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.09151887893676758
# Time to get embedding:  0.04951977729797363
# Time to get embedding:  0.027003049850463867
# Time to get embedding:  0.024997472763061523
# Time to get embedding:  0.1380326747894287
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.0260012149810791
# Time to get embedding:  0.050513505935668945
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.04800009727478027
# Time to get embedding:  0.1420431137084961
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.02451348304748535
# Time to get embedding:  0.3395545482635498
# Time to get embedding:  0.07051920890808105
# Time to get embedding:  0.2200331687927246
# Time to get embedding:  0.26655077934265137
# Time to get embedding:  0.02899765968322754
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.09052515029907227
# Time to get embedding:  0.02700495719909668
# Time to get embedding:  0.04851174354553223
# Time to get embedding:  0.10054278373718262
# Time to get embedding:  0.025975942611694336
# Time to get embedding:  0.07251715660095215
# Time to get embedding:  0.05200648307800293
# Time to get embedding:  0.07251381874084473
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.027513980865478516
# Time to get embedding:  0.04699850082397461
# Time to get embedding:  0.16603422164916992
# Time to get embedding:  0.0280001163482666
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.025518417358398438
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.049518585205078125
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.0280001163482666
# Time to get embedding:  0.025005340576171875
# Time to get embedding:  0.047513484954833984
# Time to get embedding:  0.04900479316711426
# Time to get embedding:  0.02651071548461914
# Time to get embedding:  0.3415539264678955
# Time to get embedding:  0.2955505847930908
# Time to get embedding:  0.0279998779296875
# Time to get embedding:  0.02452230453491211
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.025000810623168945
# Time to get embedding:  0.024999380111694336
# Time to get embedding:  0.04851579666137695
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.049512386322021484
# Time to get embedding:  0.028005599975585938
# Time to get embedding:  0.048000335693359375
# Time to get embedding:  0.047522544860839844
# Time to get embedding:  0.024999141693115234
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.09251785278320312
# Time to get embedding:  0.09251046180725098
# Time to get embedding:  0.025519132614135742
# Time to get embedding:  0.02600407600402832
# Time to get embedding:  0.023996591567993164
# Time to get embedding:  0.025004863739013672
# Time to get embedding:  0.13602972030639648
# Time to get embedding:  0.024994373321533203
# Time to get embedding:  0.339557409286499
# Time to get embedding:  0.11504030227661133
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.025000572204589844
# Time to get embedding:  0.04752087593078613
# Time to get embedding:  0.028998851776123047
# Time to get embedding:  0.04851651191711426
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.026004791259765625
# Time to get embedding:  0.023995399475097656
# Time to get embedding:  0.02553415298461914
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.04900002479553223
# Time to get embedding:  0.04851698875427246
# Time to get embedding:  0.024998903274536133
# Time to get embedding:  0.09251928329467773
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.02600407600402832
# Time to get embedding:  0.026510953903198242
# Time to get embedding:  0.028000354766845703
# Time to get embedding:  0.06751751899719238
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.024998903274536133
# Time to get embedding:  0.17903542518615723
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.02651190757751465
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.04700040817260742
# Time to get embedding:  0.20403575897216797
# Time to get embedding:  0.025518417358398438
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.09051752090454102
# Time to get embedding:  0.025002002716064453
# Time to get embedding:  0.02700209617614746
# Time to get embedding:  0.08851265907287598
# Time to get embedding:  0.07151532173156738
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.026519298553466797
# Time to get embedding:  0.14451980590820312
# Time to get embedding:  0.09552240371704102
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.027511119842529297
# Time to get embedding:  0.026006698608398438
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.11308097839355469
# Time to get embedding:  0.02600407600402832
# Time to get embedding:  0.09451413154602051
# Time to get embedding:  0.026515483856201172
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.025007247924804688
# Time to get embedding:  0.026514053344726562
# Time to get embedding:  0.04699897766113281
# Time to get embedding:  0.02600574493408203
# Time to get embedding:  0.02550983428955078
# Time to get embedding:  0.3305506706237793
# Time to get embedding:  0.3335542678833008
# Time to get embedding:  0.2240440845489502
# Time to get embedding:  0.025080442428588867
# Time to get embedding:  0.0279996395111084
# Time to get embedding:  0.027003765106201172
# Time to get embedding:  0.09151577949523926
# Time to get embedding:  0.09651637077331543
# Time to get embedding:  0.04851865768432617
# Time to get embedding:  0.04900002479553223
# Time to get embedding:  0.02600550651550293
# Time to get embedding:  0.024511337280273438
# Time to get embedding:  0.16252541542053223
# Time to get embedding:  0.159041166305542
# Time to get embedding:  0.0269925594329834
# Time to get embedding:  0.049520015716552734
# Time to get embedding:  0.025999784469604492
# Time to get embedding:  0.07151651382446289
# Time to get embedding:  0.0710000991821289
# Time to get embedding:  0.04852628707885742
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.09151816368103027
# Time to get embedding:  0.07251524925231934
# Time to get embedding:  0.0280001163482666
# Time to get embedding:  0.04800891876220703
# Time to get embedding:  0.02851557731628418
# Time to get embedding:  0.07100367546081543
# Time to get embedding:  0.11402773857116699
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.024001598358154297
# Time to get embedding:  0.025003671646118164
# Time to get embedding:  0.04751396179199219
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.02400660514831543
# Time to get embedding:  0.025511503219604492
# Time to get embedding:  0.09351801872253418
# Time to get embedding:  0.025000333786010742
# ...
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.025007009506225586
# Time to get embedding:  0.027514934539794922
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.0475163459777832
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.13603711128234863
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.1611788272857666
# Time to get embedding:  0.0255124568939209
# Time to get embedding:  0.025003433227539062
# Time to get embedding:  0.2625443935394287
# Time to get embedding:  0.026007652282714844
# Time to get embedding:  0.06800603866577148
# Time to get embedding:  0.024460792541503906
# Time to get embedding:  0.02400064468383789
# Time to get embedding:  0.02499842643737793
# Time to get embedding:  0.04552268981933594
# Time to get embedding:  0.07200884819030762
# Time to get embedding:  0.025524616241455078
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.04751086235046387
# Time to get embedding:  0.04900097846984863
# Time to get embedding:  0.04952073097229004
# Time to get embedding:  0.025998830795288086
# Time to get embedding:  0.02899932861328125
# Time to get embedding:  0.027005434036254883
# Time to get embedding:  0.027526378631591797
# Time to get embedding:  0.0240018367767334
# Time to get embedding:  0.026999950408935547
# Time to get embedding:  0.02700519561767578
# Time to get embedding:  0.06751775741577148
# Time to get embedding:  0.026006221771240234
# Time to get embedding:  0.024512767791748047
# Time to get embedding:  0.20087337493896484
# Time to get embedding:  0.026993989944458008
# Time to get embedding:  0.02699875831604004
# Time to get embedding:  0.0951375961303711
# Time to get embedding:  0.02800273895263672
# Time to get embedding:  0.02453136444091797
# Time to get embedding:  0.04900050163269043
# Time to get embedding:  0.025008678436279297
# Time to get embedding:  0.026511430740356445
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.024007081985473633
# Time to get embedding:  0.04751157760620117
# Time to get embedding:  0.06952118873596191
# Time to get embedding:  0.22402596473693848
# Time to get embedding:  0.15704107284545898
# Time to get embedding:  0.025141477584838867
# Time to get embedding:  0.08951878547668457
# Time to get embedding:  0.05099964141845703
# Time to get embedding:  0.02500009536743164
# Time to get embedding:  0.08951926231384277
# Time to get embedding:  0.026004314422607422
# Time to get embedding:  0.0905156135559082
# Time to get embedding:  0.026520967483520508
# Time to get embedding:  0.047998905181884766
# Time to get embedding:  0.02400040626525879
# Time to get embedding:  0.025516510009765625
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.02400040626525879
# Time to get embedding:  0.023000001907348633
# Time to get embedding:  0.023532390594482422
# Time to get embedding:  0.11051821708679199
# Time to get embedding:  0.025997638702392578
# Time to get embedding:  0.024004220962524414
# Time to get embedding:  0.07251334190368652
# Time to get embedding:  0.02599811553955078
# Time to get embedding:  0.028006553649902344
# Time to get embedding:  0.025515317916870117
# Time to get embedding:  0.31853246688842773
# Time to get embedding:  0.09350991249084473
# Time to get embedding:  0.0700068473815918
# Time to get embedding:  0.02550983428955078
# Time to get embedding:  0.09251999855041504
# Time to get embedding:  0.04900002479553223
# Time to get embedding:  0.04651522636413574
# Time to get embedding:  0.06799936294555664
# Time to get embedding:  0.025287628173828125
# Time to get embedding:  0.024999380111694336
# Time to get embedding:  0.04898977279663086
# Time to get embedding:  0.026520729064941406
# Time to get embedding:  0.0260012149810791
# Time to get embedding:  0.02500176429748535
# Time to get embedding:  0.024003267288208008
# Time to get embedding:  0.06851053237915039
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.149033784866333
# Time to get embedding:  0.049002885818481445
# Time to get embedding:  0.09052062034606934
# Time to get embedding:  0.09052038192749023
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.026038646697998047
# Time to get embedding:  0.048999786376953125
# Time to get embedding:  0.0725102424621582
# Time to get embedding:  0.02700352668762207
# Time to get embedding:  0.025996685028076172
# Time to get embedding:  0.024514198303222656
# Time to get embedding:  0.026001691818237305
# Time to get embedding:  0.026998519897460938
# Time to get embedding:  0.0240018367767334
# Time to get embedding:  0.027519702911376953
# Time to get embedding:  0.02500319480895996
# Time to get embedding:  0.20103740692138672
# Time to get embedding:  0.04999947547912598
# Time to get embedding:  0.025519132614135742
# Time to get embedding:  0.04999995231628418
# Time to get embedding:  0.06952095031738281
# Time to get embedding:  0.02500152587890625
# Time to get embedding:  0.025998353958129883
# Time to get embedding:  0.3055570125579834
# Time to get embedding:  0.026515960693359375
# Time to get embedding:  0.026000022888183594
# Time to get embedding:  0.04800295829772949
# Time to get embedding:  0.07052063941955566
# Time to get embedding:  0.026005268096923828
# Time to get embedding:  0.025376558303833008
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.02400803565979004
# Time to get embedding:  0.02900528907775879
# Time to get embedding:  0.09251880645751953
# Time to get embedding:  0.026511192321777344
# Time to get embedding:  0.02399897575378418
# Time to get embedding:  0.024996519088745117
# Time to get embedding:  0.026011943817138672
# Time to get embedding:  0.13406896591186523
# Time to get embedding:  0.02598428726196289
# Time to get embedding:  0.3315773010253906
# Time to get embedding:  0.16063261032104492
# Time to get embedding:  0.024998903274536133
# Time to get embedding:  0.046511173248291016
# Time to get embedding:  0.04800915718078613
# Time to get embedding:  0.027996301651000977
# Time to get embedding:  0.026512861251831055
# Time to get embedding:  0.04500269889831543
# Time to get embedding:  0.04651641845703125
# Time to get embedding:  0.20003604888916016
# Time to get embedding:  0.026003599166870117
# Time to get embedding:  0.02600264549255371
# Time to get embedding:  0.11351132392883301
# Time to get embedding:  0.0280148983001709
# Time to get embedding:  0.27315258979797363
# Time to get embedding:  0.02800917625427246
# Time to get embedding:  0.04851365089416504
# Time to get embedding:  0.11851644515991211
# Time to get embedding:  0.05252385139465332
# Time to get embedding:  0.025000572204589844
# Time to get embedding:  0.07451510429382324
# Time to get embedding:  0.05100584030151367
# Time to get embedding:  0.1420431137084961
# Time to get embedding:  0.13750982284545898
# Time to get embedding:  0.05000162124633789
# Time to get embedding:  0.024515390396118164
# Time to get embedding:  0.04900193214416504
# Time to get embedding:  0.02851390838623047
# Time to get embedding:  0.02600383758544922
# Time to get embedding:  0.045000314712524414
# Time to get embedding:  0.04651689529418945
# Time to get embedding:  0.023998498916625977
# Time to get embedding:  0.13851690292358398
# Time to get embedding:  0.09051966667175293
# Time to get embedding:  0.02701258659362793
# Time to get embedding:  0.04951643943786621
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.026009321212768555
# Time to get embedding:  0.08652901649475098
# Time to get embedding:  0.09052467346191406
# Time to get embedding:  0.024513959884643555
# Time to get embedding:  0.24886488914489746
# Time to get embedding:  0.05452322959899902
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.024997234344482422
# Time to get embedding:  0.11052370071411133
# Time to get embedding:  0.02700638771057129
# Time to get embedding:  0.04951882362365723
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.02500605583190918
# Time to get embedding:  0.18203449249267578
# Time to get embedding:  0.02552509307861328
# Time to get embedding:  0.1605222225189209
# Time to get embedding:  0.02600693702697754
# Time to get embedding:  0.2705388069152832
# Time to get embedding:  0.026011943817138672
# Time to get embedding:  0.1150362491607666
# Time to get embedding:  0.026996850967407227
# Time to get embedding:  0.024001121520996094
# Time to get embedding:  0.04652714729309082
# Time to get embedding:  0.026003360748291016
# Time to get embedding:  0.026997804641723633
# Time to get embedding:  0.023998498916625977
# Time to get embedding:  0.024520158767700195
# Time to get embedding:  0.02400040626525879
# Time to get embedding:  0.04600119590759277
# Time to get embedding:  0.13405585289001465
# Time to get embedding:  0.17151451110839844
# Time to get embedding:  0.0495305061340332
# Time to get embedding:  0.04999971389770508
# Time to get embedding:  0.3361082077026367
# Time to get embedding:  0.024993181228637695
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.1295311450958252
# Time to get embedding:  0.024530410766601562
# Time to get embedding:  0.04700589179992676
# Time to get embedding:  0.2425687313079834
# Time to get embedding:  0.028995037078857422
# Time to get embedding:  0.07051706314086914
# Time to get embedding:  0.0690000057220459
# Time to get embedding:  0.02552628517150879
# Time to get embedding:  0.02499866485595703
# Time to get embedding:  0.02499866485595703
# Time to get embedding:  0.02400040626525879
# Time to get embedding:  0.026520967483520508
# Time to get embedding:  0.025995969772338867
# Time to get embedding:  0.04600381851196289
# Time to get embedding:  0.02651810646057129
# Time to get embedding:  0.0260012149810791
# Time to get embedding:  0.02399897575378418
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.02652263641357422
# Time to get embedding:  0.04800009727478027
# Time to get embedding:  0.025996923446655273
# Time to get embedding:  0.0475156307220459
# Time to get embedding:  0.04699969291687012
# Time to get embedding:  0.026518583297729492
# Time to get embedding:  0.049001216888427734
# Time to get embedding:  0.02700018882751465
# Time to get embedding:  0.33807873725891113
# Time to get embedding:  0.33354711532592773
# Time to get embedding:  0.34256458282470703
# Time to get embedding:  0.3379848003387451
# Time to get embedding:  0.33454465866088867
# Time to get embedding:  0.05051064491271973
# Time to get embedding:  0.028000831604003906
# Time to get embedding:  0.0240018367767334
# Time to get embedding:  0.11151981353759766
# Time to get embedding:  0.029070377349853516
# Time to get embedding:  0.2970399856567383
# Time to get embedding:  0.02651190757751465
# Time to get embedding:  0.04699993133544922
# Time to get embedding:  0.04952216148376465
# Time to get embedding:  0.33657002449035645
# Time to get embedding:  0.3335380554199219
# Time to get embedding:  0.3096160888671875
# Time to get embedding:  0.04799962043762207
# Time to get embedding:  0.02499985694885254
# Time to get embedding:  0.025518417358398438
# Time to get embedding:  0.025997400283813477
# Time to get embedding:  0.1780250072479248
# Time to get embedding:  0.027003049850463867
# Time to get embedding:  0.02599930763244629
# Time to get embedding:  0.06952619552612305
# Time to get embedding:  0.11251258850097656
# Time to get embedding:  0.02600264549255371
# Time to get embedding:  0.02500629425048828
# Time to get embedding:  0.027515888214111328
# Time to get embedding:  0.02499532699584961
# Time to get embedding:  0.2245793342590332
# Time to get embedding:  0.025516748428344727
# Time to get embedding:  0.10851597785949707
# Time to get embedding:  0.20095300674438477
# Time to get embedding:  0.02499866485595703
# Time to get embedding:  0.025000333786010742
# Time to get embedding:  0.3380587100982666
# Time to get embedding:  0.07200860977172852
# Time to get embedding:  0.027012109756469727
# Time to get embedding:  0.1550302505493164
# Time to get embedding:  0.027998924255371094
# Time to get embedding:  0.10752701759338379
# Time to get embedding:  0.048512935638427734
# Time to get embedding:  0.06850957870483398
# Time to get embedding:  0.028002023696899414
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.02500629425048828
# Time to get embedding:  0.13103175163269043
# Time to get embedding:  0.0260007381439209
# Time to get embedding:  0.0260012149810791
# Time to get embedding:  0.027002573013305664
# Time to get embedding:  0.028514385223388672
# Time to get embedding:  0.06799936294555664
# Time to get embedding:  0.025517702102661133
# Time to get embedding:  0.026002883911132812
# Time to get embedding:  0.024999141693115234
# Time to get embedding:  0.027004480361938477
# Time to get embedding:  0.025524616241455078
# Time to get embedding:  0.15251851081848145
# Time to get embedding:  0.05051827430725098
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.0915079116821289
# Time to get embedding:  0.06851816177368164
# Time to get embedding:  0.025994539260864258
# Time to get embedding:  0.02599644660949707
# Time to get embedding:  0.02500605583190918
# Time to get embedding:  0.02651357650756836
# Time to get embedding:  0.06900358200073242
# Time to get embedding:  0.02650928497314453
# Time to get embedding:  0.02700042724609375
# Time to get embedding:  0.024999618530273438
# Time to get embedding:  0.04952120780944824
# Time to get embedding:  0.06899857521057129
# Time to get embedding:  0.02551746368408203
# Time to get embedding:  0.04900503158569336
# Time to get embedding:  0.0495150089263916
# Time to get embedding:  0.02599954605102539
# Time to get embedding:  0.02600407600402832
# Time to get embedding:  0.02299666404724121
# Time to get embedding:  0.0695183277130127
# Time to get embedding:  0.02599787712097168
# Time to get embedding:  0.04952216148376465
# Time to get embedding:  0.04999971389770508
# Time to get embedding:  0.024516582489013672
# Time to get embedding:  0.02599811553955078
# Time to get embedding:  0.15451836585998535
# Time to get embedding:  0.07051587104797363
# Time to get embedding:  0.0915217399597168
# Time to get embedding:  0.026000261306762695
# Time to get embedding:  0.02600884437561035
# Time to get embedding:  0.026514053344726562
# Time to get embedding:  0.025005102157592773
# Time to get embedding:  0.11251354217529297
# Time to get embedding:  0.13952112197875977
# Time to get embedding:  0.026520490646362305
# Time to get embedding:  0.13351750373840332
# Time to get embedding:  0.33055853843688965
# Time to get embedding:  0.33806467056274414
# Time to get embedding:  0.33556413650512695
# Time to get embedding:  0.2455449104309082
# Time to get embedding:  0.04900002479553223
# Time to get embedding:  0.15066123008728027
# Time to get embedding:  0.025996685028076172
# Time to get embedding:  0.0260009765625
# Time to get embedding:  0.0485224723815918
# Time to get embedding:  0.025009870529174805
# Time to get embedding:  0.04698824882507324
# Time to get embedding:  0.04651641845703125
# Time to get embedding:  0.026001453399658203
# Time to get embedding:  0.09051656723022461
# Time to get embedding:  0.024000167846679688
# Time to get embedding:  0.06951665878295898
# Time to get embedding:  0.1345233917236328
# Time to get embedding:  0.048508644104003906
# Time to get embedding:  0.11051678657531738
# Time to get embedding:  0.04800152778625488
# Time to get embedding:  0.0475163459777832
# Time to get embedding:  0.024997949600219727
# Time to get embedding:  0.33653950691223145
# Time to get embedding:  0.34707045555114746
# Time to get embedding:  0.3471510410308838
# Time to get embedding:  0.34207677841186523
# Time to get embedding:  0.34154748916625977
# Time to get embedding:  0.3420720100402832
# Time to get embedding:  0.3365511894226074
# Time to get embedding:  0.3355579376220703
# Time to get embedding:  0.33806586265563965
# Time to get embedding:  0.33655762672424316
# Time to get embedding:  0.34905481338500977
# Time to get embedding:  0.34654927253723145
# Time to get embedding:  0.34155869483947754

# %%
torch.cuda.empty_cache()

# %%
# salvando o dataframe
df_reviews_text.to_parquet('../data/DatasetsLimpos/review_text.parquet')
